# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("rohit.jpg")

# %%
plt.imshow(img)

# %%
img.size
# Out:
# 7502508

# %%
img.shape
# Out:
# (1564, 1599, 3)

# %%
1564*1599*3
# Out:
# 7502508

# %%
a = img[50, 50]

# %%
a
# Out:
# array([206, 221, 213], dtype=uint8)

# %%
img1=cv2.imread("rohit.jpg")

# %%
b,g,r = cv2.split(img1)

# %%
r.shape, g.shape, b.shape
# Out:
# ((1564, 1599), (1564, 1599), (1564, 1599))

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
img_rgb1 = cv2.resize(img_rgb, (100,200))
plt.imshow(img_rgb1)

# %%
img_f1 = cv2.flip(img_rgb, 0)
plt.imshow(img_f1)

# %%
img_rgb.shape
# Out:
# (1564, 1599, 3)

# %%
x_offset = 1564 - 500
y_offset = 1564 - 500

# %%
rows, cols, channels = img_rgb.shape

# %%
roi = img_rgb[0:x_offset, 0:y_offset]
plt.imshow(roi)

# %%
roi = img_rgb[x_offset:rows, y_offset:cols]
plt.imshow(roi)

# %%
roi = img_rgb[350:570, 0:cols]
plt.imshow(roi)

# %%
plt.imshow(img_rgb)

# %%
f = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img_rgb, text = "rohit", org=(0, 100), fontFace=f,fontScale=2,color=(155,200,105), thickness=3)
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)
